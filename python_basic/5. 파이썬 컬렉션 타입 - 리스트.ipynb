# %% [markdown]
# # **1. 컬렉션 타입**
# 여러 개의 데이터 항목을 하나의 단위로 관리할 수 있게 해주는 데이터 구조를 의미합니다. 이것은 여러 개의 데이터를 하나의 변수에 저장하고, 관리할 수 있게 해줍니다. 파이썬에서는 리스트, 튜플, 세트, 딕셔너리 등이 기본적인 컬렉션 타입에 속합니다.

# %% [markdown]
# # **2. 리스트***
# 여러 값들을 하나의 변수에 저장하고 관리할 수 있게 해주는 순차적인 자료구조입니다.
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FrbbGS%2FbtsNlJ3pII6%2FAAAAAAAAAAAAAAAAAAAAADZ_4vWsTlsb7UDjjXvI68BXsS1bijEAnOMx_1PO2yF8%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1753973999%26allow_ip%3D%26allow_referer%3D%26signature%3DhqsmPEYZ9sRlmMsQAtHgh8cUCpE%253D'>

# %% [markdown]
# ### 1. 생성
# 리스트는 대괄호 [ ]를 사용하여 생성하며, 내부에 포함된 각 항목들은 쉼표로 구분됩니다.

# %%
li1 = [1, 3, 5, 7, 9]
print(li1)
print(type(li1))
# Out:
# [1, 3, 5, 7, 9]
# <class 'list'>

# %%
# 리스트 함수에 넣은 이유?
# 형변환 하려고 쓰는 함수 (리스트, 튜플, 딕셔너리, 셋 등 여러 자료 구조들을 리스트로 형 변환 시키기 위한 함수)
li2 = list([1, 3, 5, 7, 9]) #리스트 함수에 넣음
print(li2)
print(type(li2))
# Out:
# [1, 3, 5, 7, 9]
# <class 'list'>

# %%
li3 = ['김사과', '반하나', '오렌지', '이메론']
print(li3)
print(type(li3))
# Out:
# ['김사과', '반하나', '오렌지', '이메론']
# <class 'list'>

# %%
li4 = [1, 50.5, '김사과', True] # 각자 타입이 다른 데이터를 저장
print(li4)
print(type(li4))
print(type(li4[0]))
print(type(li4[-1]))
# Out:
# [1, 50.5, '김사과', True]
# <class 'list'>
# <class 'int'>
# <class 'bool'>

# %%
print(li4[0])
print(type(li4[0]))
print(li4[0])
print(li4[1])
print(li4[2])
print(li4[3])
# Out:
# 1
# <class 'int'>
# 1
# 50.5
# 김사과
# True

# %%
print(type(li4[0]))
print(type(li4[1]))
print(type(li4[2]))
print(type(li4[3]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### 2. 인덱싱
# 리스트의 각 항목은 위치(인덱스)를 가지고 있으며, 인덱스를 사용하여 접근할 수 있습니다. 인덱스는 0부터 시작합니다.
#
#
#
# - 인덱싱은 리스트에서 '하나의 요소'를 꺼내는 것입니다.
# - 결과는 → 꺼낸 하나의 값(값 자체=스칼라)입니다. 스칼라가 모인 걸 벡터라고 함
# - 대괄호로 감싸지지 않습니다.
# 스칼라 : 10
# 벡터 [10, 20]
# 행렬 [ [ ],[ ] ]
# => 인덱싱을 하면 차원이 하나씩 벗겨진다.

# %%
li1 = [1, 3, 5, 7, 9]
print(li1) #대괄호가 없어져 있음, 스칼라가 됨. 차원이 줄어든다.
print(li1[0])
print(li1[-1])
print(li1[0] + li1[-1])
# Out:
# [1, 3, 5, 7, 9]
# 1
# 9
# 10

# %%
li1 = ['1', 3, 5, 7, '9']
print(li1[0] + li1[-1])
# Out:
# 19

# %%
li2 = [1, 2, '파이썬', ['김사과', '오렌지']]
print(li2)
print(type(li2))
print(li2[1])
print(type(li2[1]))
print(li2[3])
print(type(li2[3]))
print(li2[3][1])
print(type(li2[3][1]))
# Out:
# [1, 2, '파이썬', ['김사과', '오렌지']]
# <class 'list'>
# 2
# <class 'int'>
# ['김사과', '오렌지']
# <class 'list'>
# 오렌지
# <class 'str'>

# %%
li3 = [1, 2, 3, ['김사과', '오렌지', '반하나', ['🍟','🌭','🥩','🍗']]]
print(li3)
print(li3[2])
print(li3[-1])
print(li3[-1][-2])
print(li3[-1][-1][-2])
print(li3[-1][-1][-1])
print(type(li3[-1][-1][-1]))
# Out:
# [1, 2, 3, ['김사과', '오렌지', '반하나', ['🍟', '🌭', '🥩', '🍗']]]
# 3
# ['김사과', '오렌지', '반하나', ['🍟', '🌭', '🥩', '🍗']]
# 반하나
# 🥩
# 🍗
# <class 'str'>

# %% [markdown]
# ### 3. 슬라이싱
# 리스트의 일부분만을 추출할 수 있습니다.
#
#
#
# - 슬라이싱은 리스트에서 '여러 개 요소'를 잘라서 새로운 리스트로 만드는 것입니다.
# - 결과는 → 잘라낸 "리스트" (대괄호로 감싸진 새로운 리스트)입니다.
#
# **인덱싱과 다르게 차원이 변하지 않음**
#
# ```
# 리스트[start:end:step]
# ```
#
# - start: 어디서 시작할지 (포함)
# - end: 어디까지 갈지 (끝 인덱스는 포함하지 않음)
# - step: 몇 칸씩 이동할지

# %%
li1 = [10, 20, 30, 40, 50, 60]
print(li1)
print(li1[0:5:2])
print(li1[0::2])
print(li1[::2])
print(li1[2::])
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 30, 50]
# [10, 30, 50]
# [10, 30, 50]
# [30, 40, 50, 60]

# %%
li2 = li1 #1i2에 li1의 메모리 주소를 넣은 것
print(li2)
li2[0] = 100
print(li2)
print(li1) #같이 바뀌어 있음 (같은 메모리 주소를 쓰고 있기 때문)
# Out:
# [10, 20, 30, 40, 50, 60]
# [100, 20, 30, 40, 50, 60]
# [100, 20, 30, 40, 50, 60]

# %%
li3 = [1, 2, 3, ['김사과', '오렌지', '반하나', ['🍟','🌭','🥩','🍗']]]
print(li3[2:3])
print(li3[2:2])
print(li3[3][:2])
# Out:
# [3]
# []
# ['김사과', '오렌지']

# %% [markdown]
# ### 4. 변경 가능
# 리스트의 항목들은 변경할 수 있습니다. 즉, 리스트의 항목들을 수정, 추가, 삭제할 수 있습니다.

# %%
li4 = [10, 20, 30, 40, 50]
# 슬라이싱을 이용하여 요소를 추가한 경우 리스트에 데이터만 포함
li4[1:2] = ['😁','😂','😎','😍']
print(li4)
# Out:
# [10, '😁', '😂', '😎', '😍', 30, 40, 50]

# %%
li4 = [10, 20, 30, 40, 50]
# 슬라이싱을 이용하여 요소를 추가한 경우 리스트에 데이터만 포함
li4[1:3] = [['😁','😂','😎','😍']] #그냥 그 사이이기 때문에
print(li4)
# Out:
# [10, ['😁', '😂', '😎', '😍'], 40, 50]

# %%
li4 = [10, 20, 30, 40, 50]
# 인덱싱을 이용하여 요소를 추가한 경우 리스트 안에 리스트를 만들고 포함
li4[1] = ['😁','😂','😎','😍']
print(li4)
# Out:
# [10, ['😁', '😂', '😎', '😍'], 30, 40, 50]

# %%
li4 = [10, 20, 30, 40, 50]
print(li4[1:3])
li4[1:3] = [] # 빈 리스트를 슬라이싱을 통해 저장하면 해당 요소가 삭제됨
print(li4)
# Out:
# [20, 30]
# [10, 40, 50]

# %%
li4 = [10, 20, 30, 40, 50]
print(li4[1:2])
print(li4[1])
li4[1] = []
print(li4)
# Out:
# [20]
# 20
# [10, [], 30, 40, 50]

# %%
li4 = [10, 20, 30, 40, 50]
print(li4)
del li4[1]
print(li4)
# Out:
# [10, 20, 30, 40, 50]
# [10, 30, 40, 50]

# %% [markdown]
# ### 5. 연산
# 리스트 간의 + 연산으로 리스트를 결합할 수 있고, * 연산으로 리스트를 반복할 수 있습니다.

# %%
li5 = [10, 20, 30]
li6 = [40, 50, 60]
print(li5 + li6)
print(li6 + li5)
# Out:
# [10, 20, 30, 40, 50, 60]
# [40, 50, 60, 10, 20, 30]

# %%
li5 = [10, 20, 30]
li6 = li5 + [40, 50, 60] # [10, 20, 30] + [40, 50, 60]
print(li6)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
li6 = [10, 20, 30]
li6 += [40, 50, 60] # li6 = li6 + [40, 50, 60]
print(li6)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
li6 = [10, 20, 30]
print(li6 * 3)
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %% [markdown]
# ### 6. 함수와 메서드
# 리스트를 다루기 위한 여러 함수와 메소드들이 있습니다.

# %%
# len(): 객체의 길이를 반환하는 파이썬의 기본 내장 함수
li6 = [10, 20, 30]
print(len(li6))
# Out:
# 3

# %%
# append(): 리스트 요소의 끝에 새로운 요소를 추가
li6 = [10, 20, 30]
print(li6)

li6.append(100) #매개변수가 1개만 들어갈 수 있음
print(li6)
# li6.append(200, 300)
li6.append([200, 300])
print(li6)
# Out:
# [10, 20, 30]
# [10, 20, 30, 100]
# [10, 20, 30, 100, [200, 300]]

# %%
# extend(): 리스트 요소의 끝에 새로운 여러 요소를 추가
li6 = [10, 20, 30]
print(li6)

# li6.extend(100) -> 이거 오류남
li6.extend([100])
print(li6)
li6.extend([200, 300, 400])
print(li6)
# Out:
# [10, 20, 30]
# [10, 20, 30, 100]
# [10, 20, 30, 100, 200, 300, 400]

# %%
# pop(): 리스트 마지막 요소를 삭제하고 삭제된 요소를 반환
li6 = [10, 20, 30]
print(li6)

# print(li6.pop())
temp = li6.pop()
print(li6)
print(temp)
# Out:
# [10, 20, 30]
# [10, 20]
# 30

# %%
# index(): 리스트에서 특정 요소의 값 인덱스를 반환
li6 = [10, 20, 30]
print(li6)

print(li6.index(30))
# print(li6.index(100)) # 값이 없으면 에러
# Out:
# [10, 20, 30]
# 2

# %%
# reverse(): 리스트의 요소들의 순서를 반대로 설정
li7 = [100, 50, 70, 60, 20]
print(li7)

li7.reverse() #inplace 메소드임

rev = list(reversed(li7))
# rev = [5,4,3,2,1], li7는 그대로 [1,2,3,4,5]

print(rev)
print(li7)
# Out:
# [100, 50, 70, 60, 20]
# [100, 50, 70, 60, 20]
# [20, 60, 70, 50, 100]

# %%
# 슬라이싱을 사용하여 리스트의 요소들의 순서를 반대로 설정하는 방법
li7 = [100, 50, 70, 60, 20]
print(li7[:]) # [0:5]
print(li7[0:5])
print(li7[::])    # step이 생략
print(li7[0:5:1]) # step의 기본값은 1
print(li7[0:5:2]) # step을 2로 설정
# Out:
# [100, 50, 70, 60, 20]
# [100, 50, 70, 60, 20]
# [100, 50, 70, 60, 20]
# [100, 50, 70, 60, 20]
# [100, 70, 20]

# %%
li7 = [100, 50, 70, 60, 20]
print(li7[::-1])
# step이 -1일 경우 start의 기본값은 length-1, end의 기본값은 -1으로 설정
print(li7[-1::-1])
print(li7[4::-1])
print(li7[4:None:-1])
# Out:
# [20, 60, 70, 50, 100]
# [20, 60, 70, 50, 100]
# [20, 60, 70, 50, 100]
# [20, 60, 70, 50, 100]

# %% [markdown]
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2Fcg3Iuv%2FbtsNAjqwL9V%2FAAAAAAAAAAAAAAAAAAAAAFj7FeW62TPkJyljHU7yEyjqX2-oNp2g_OXRZXLOuNcl%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1753973999%26allow_ip%3D%26allow_referer%3D%26signature%3DfTipG819P5p%252BD6dq0wwCfwUbJu8%253D'>
#
# > step이 음수인 경우, end의 기본값은 -1입니다. 하지만 리스트의 마지막 요소 역시 인덱스 -1이므로, 전체를 역순으로 출력할 때는 end를 생략하여 사용합니다.

# %%
# sort(): 리스트의 요소를 오름차순으로 정렬
li7 = [100, 50, 70, 60, 20]
print(li7)
# Out:
# [100, 50, 70, 60, 20]

# %%
li7.sort()
print(li7)
# sort(reverse=True): 리스트의 요소를 내림차순으로 정렬
li7.sort(reverse=True) #inplace 메서드
print(li7)
# Out:
# [20, 50, 60, 70, 100]
# [100, 70, 60, 50, 20]

# %%
li8 = ['Apple', 'apple', 'orange', 'banana', 'melon']
li8.sort()
print(li8)
# 문자열 오름차순 : 대문자 먼저, a 먼저 ...
# Out:
# ['Apple', 'apple', 'banana', 'melon', 'orange']

# %%
# sorted(): 모든 요소를 정렬한 후 반환해주는 함수
li7 = [100, 50, 70, 60, 20]
print(li7)

result = sorted(li7) #오름차순
print(li7)
print(result)

result = sorted(li7, reverse=True) #내림차순
print(li7)
print(result)
# Out:
# [100, 50, 70, 60, 20]
# [100, 50, 70, 60, 20]
# [20, 50, 60, 70, 100]
# [100, 50, 70, 60, 20]
# [100, 70, 60, 50, 20]

# %%
# count(): 리스트에서 특정 요소의 갯수를 반환
li9 = [10, 20, 30, 50, 20, 40, 30, 20]
print(li9)

print(li9.count(20))
print(li9.count(100))
# Out:
# [10, 20, 30, 50, 20, 40, 30, 20]
# 3
# 0
