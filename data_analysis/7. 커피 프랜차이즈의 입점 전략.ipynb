# %% [markdown]
# # **1. 스타벅스 옆엔 이디야와 올리브영이 있다?**
#
# https://kid.chosun.com/site/data/html_dir/2022/06/02/2022060202963.html

# %% [markdown]
# # **2. 스타벅스 정보 크롤링**

# %%
import pandas as pd

df_starbucks = pd.read_csv("/content/drive/MyDrive/AI활용 소프트웨어 개발/10. 파이썬 웹 서비스/11. 데이터 분석/starbucks_seoul.csv")
df_starbucks
# Out:
#          store                                   addr        lat         lng
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 639      상봉역                  서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 640       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 641      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 642      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 643      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [644 rows x 4 columns]

# %%
df_starbucks = df_starbucks.set_axis(['지점명', '지점주소', '지점위도', '지점경도'], axis=1).reset_index(drop=True)
df_starbucks
# Out:
#            지점명                                   지점주소       지점위도        지점경도
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 639      상봉역                  서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 640       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 641      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 642      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 643      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [644 rows x 4 columns]

# %%
df = pd.read_csv("/content/drive/MyDrive/AI활용 소프트웨어 개발/10. 파이썬 웹 서비스/11. 데이터 분석/소상공인시장진흥공단_상가(상권)정보_서울_202503.csv")
df.head()
# Out:
#                  상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1  MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2  MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
# 3  MA010120220800000084         고향집  NaN        I2       음식      I201
# 4  MA010120220800000090        보석나라  NaN        G2       소매      G217
#
#     상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0      비알코올     I21201          카페   I56229  ...  1111014000100280021026727
# 1    부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010800113080025020133
# 2    부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1120012200100040011000899
# 3         한식    I20101      백반/한정식   I56111  ...  1111015400100800000000001
# 4  시계·귀금속 소매    G21701  시계/귀금속 소매업   G47830  ...  1153010700103590008007958
#
#       건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0     NaN   서울특별시 종로구 삼청로 122-1  110230  3053  NaN  NaN  NaN  126.981840
# 1  강남오피스텔  서울특별시 서초구 서초대로73길 40  137856  6612  NaN   11  NaN  127.024563
# 2     NaN  서울특별시 성동구 용답중앙15길 18  133847  4805  NaN    1  NaN  127.054262
# 3     NaN   서울특별시 종로구 돈화문로4길 30  110430  3193  NaN  NaN  NaN  126.993820
# 4     NaN    서울특별시 구로구 개봉로3길 23  152815  8353  NaN    1  NaN  126.855046
#
#           위도
# 0  37.586250
# 1  37.500924
# 2  37.564786
# 3  37.570025
# 4  37.486242
#
# [5 rows x 39 columns]

# %%
shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540517 entries, 0 to 540516
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     540517 non-null  object
#  1   상호명        540517 non-null  object
#  2   지점명        48544 non-null   object
#  3   상권업종대분류코드  540517 non-null  object
#  4   상권업종대분류명   540517 non-null  object
#  5   상권업종중분류코드  540517 non-null  object
#  6   상권업종중분류명   540517 non-null  object
#  7   상권업종소분류코드  540517 non-null  object
#  8   상권업종소분류명   540517 non-null  object
#  9   표준산업분류코드   540317 non-null  object
#  10  표준산업분류명    540317 non-null  object
#  11  시도코드       540517 non-null  int64
#  12  시도명        540517 non-null  object
#  13  시군구코드      540517 non-null  int64
#  14  시군구명       540517 non-null  object
#  15  행정동코드      540517 non-null  int64
#  16  행정동명       540517 non-null  object
#  17  법정동코드      540517 non-null  int64
#  18  법정동명       540517 non-null  object
#  19  지번코드       540517 non-null  int64
#  20  대지구분코드     540517 non-null  int64
#  21  대지구분명      540517 non-null  object
#  22  지번본번지      540460 non-null  float64
#  23  지번부번지      448378 non-null  float64
#  24  지번주소       540517 non-null  object
#  25  도로명코드      540517 non-null  int64
#  26  도로명        540517 non-null  object
#  27  건물본번지      540516 non-null  float64
#  28  건물부번지      70031 non-null   float64
#  29  건물관리번호     540516 non-null  object
#  30  건물명        265014 non-null  object
#  31  도로명주소      540517 non-null  object
#  32  구우편번호      540517 non-null  int64
#  33  신우편번호      540517 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        370779 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         540517 non-null  float64
#  38  위도         540517 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 160.8+ MB

# %%
# 메가커피(메가엠지씨) 데이터 필터링
# contains(): 특정 문자열 포함 여부에 따라 True, False를 반환
# case=False: 대소문자를 구분하지 않겠다는 설정
# na=False: 결측치(NaN) 처리. 결측치가 있는 경우 False로 간주하여 결과에 포함되지 않음
df[df["상호명"].str.contains("메가엠지씨", case=False, na=False)]
# Out:
#                       상가업소번호              상호명   지점명 상권업종대분류코드 상권업종대분류명  \
# 5212    MA010120220800062311  메가엠지씨커피논현아크로힐스점   NaN        I2       음식
# 6045    MA010120220800090900  메가엠지씨커피천왕이펜하우스점   NaN        I2       음식
# 7002    MA010120220800105068        메가엠지씨커피신월  사거리점        I2       음식
# 34918   MA010120220800524873        메가엠지씨커피미아   롯데점        I2       음식
# 43667   MA010120220800655475     메가엠지씨커피미아현대점   NaN        I2       음식
# ...                      ...              ...   ...       ...      ...
# 536196  MA0106202305A0036963        메가엠지씨커피석촌   한솔점        I2       음식
# 537112  MA0106202212A0036884     메가엠지씨커피신논현역점   NaN        I2       음식
# 537189  MA0106202306A0036928    메가엠지씨커피역삼GFC점   NaN        I2       음식
# 539813  MA0101202502A0100676  메가엠지씨커피래미안라그란데점   NaN        I2       음식
# 540482  MA0101202502A0103021    메가엠지씨커피쌍문세라믹점   NaN        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 5212        I212    비알코올     I21201       카페   I56221  ...
# 6045        I212    비알코올     I21201       카페   I56221  ...
# 7002        I212    비알코올     I21201       카페   I56221  ...
# 34918       I212    비알코올     I21201       카페   I56221  ...
# 43667       I212    비알코올     I21201       카페   I56221  ...
# ...          ...      ...       ...      ...      ...  ...
# 536196      I212    비알코올     I21201       카페   I56221  ...
# 537112      I212    비알코올     I21201       카페   I56221  ...
# 537189      I212    비알코올     I21201       카페   I56221  ...
# 539813      I212    비알코올     I21201       카페   I56221  ...
# 540482      I212    비알코올     I21201       카페   I56221  ...
#
#                            건물관리번호         건물명                 도로명주소   구우편번호  \
# 5212    1168010800102760000026382     아크로힐스논현     서울특별시 강남구 언주로 604  135833
# 6045    1153011100100270000000029  천왕이펜하우스4단지      서울특별시 구로구 천왕로 29  152130
# 7002    1147010300101660003011420         NaN  서울특별시 양천구 남부순환로40길 3  158829
# 34918   1130510100100720005028796         NaN   서울특별시 강북구 도봉로10길 38  142804
# 43667   1129013400105170014024754         NaN    서울특별시 성북구 동소문로 309  136800
# ...                           ...         ...                   ...     ...
# 536196  1171010500102850004009886         NaN   서울특별시 송파구 백제고분로 354  138847
# 537112  1168010800101990005009372         NaN    서울특별시 강남구 강남대로 480  135827
# 537189  1168010100107380009028033         NaN     서울특별시 강남구 논현로 429  135924
# 539813  1123011000102570042002921     래미안라그란데  서울특별시 동대문구 이문로35길 12  130829
# 540482  1132010500100190015007350        다보빌딩      서울특별시 도봉구 도당로 14  132858
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 5212    6102  NaN    1  NaN  127.038399  37.509498
# 6045    8364  NaN    1  NaN  126.838493  37.480877
# 7002    7910  NaN  NaN  NaN  126.828318  37.535040
# 34918   1216  NaN    1  NaN  127.031034  37.614376
# 43667   2730  NaN    1  NaN  127.028585  37.607719
# ...      ...  ...  ...  ...         ...        ...
# 536196  5684  NaN    1  NaN  127.105620  37.504267
# 537112  6120  NaN  NaN  NaN  127.024565  37.505294
# 537189  6237  NaN    2  NaN  127.037421  37.499137
# 539813  2404  NaN  NaN  NaN  127.060233  37.600084
# 540482  1393  NaN    1  NaN  127.035167  37.659497
#
# [783 rows x 39 columns]

# %%
df[df["상호명"].str.contains("메가커피", case=False, na=False)]
# Out:
#                       상가업소번호           상호명    지점명 상권업종대분류코드 상권업종대분류명  \
# 11397   MA010120220800186190     식빵은여기메가커피    NaN        I2       음식
# 34455   MA010120220800505619         메가커피우    장산점        I2       음식
# 79183   MA010120220802241927          메가커피    마곡점        I2       음식
# 82047   MA010120220802678209        메가커피문정  아이파크점        I2       음식
# 89278   MA010120220803145703        메가커피현대    시장점        I2       음식
# 95297   MA010120220803387874        메가커피신곡    시장점        I2       음식
# 141402  MA010120220804156243     메가커피신도림역점    NaN        I2       음식
# 141793  MA010120220804149613          메가커피    장안점        I2       음식
# 166339  MA010120220804461630      메가커피지하도점    강남역        I2       음식
# 177125  MA010120220804968967     메가커피잠실레이크   팰리스점        I2       음식
# 185290  MA010120220805197325        메가커피노원   로데오점        I2       음식
# 198677  MA010120220806394682        메가커피숙대    NaN        I2       음식
# 206968  MA010120220806689213        메가커피이수    태평점        I2       음식
# 218327  MA010120220807070602          메가커피    NaN        I2       음식
# 229663  MA010120220808069247       메가커피신도봉    시장점        I2       음식
# 231371  MA010120220808147311      메가커피수색자이    NaN        I2       음식
# 231557  MA010120220808157025     메가커피노량진역점    NaN        I2       음식
# 237155  MA010120220808463723          메가커피    NaN        I2       음식
# 246255  MA010120220808836788      메가커피고투몰점    NaN        I2       음식
# 247539  MA010120220808992892    메가커피북한산정릉점    NaN        I2       음식
# 253927  MA010120220809673319        메가커피신길    중앙점        I2       음식
# 262489  MA010120220810024637          메가커피   왕십리점        I2       음식
# 263992  MA010120220810074917     메가커피사가정역점    NaN        I2       음식
# 264906  MA010120220810112788      메가커피양천신정    중앙점        I2       음식
# 266193  MA010120220810150865     메가커피연남숲길점    NaN        I2       음식
# 279603  MA010120220811952416       메가커피서울대    입구점        I2       음식
# 281399  MA010120220811699241      메가커피신상도점    NaN        I2       음식
# 283780  MA010120220811858271      메가커피상계역점    NaN        I2       음식
# 297337  MA010120220812511902          메가커피    공덕점        I2       음식
# 302814  MA010120220812196839     메가커피문정로데오    NaN        I2       음식
# 304818  MA010120220812685091       메가커피고대점    NaN        I2       음식
# 314600  MA010120220813125772     메가커피수락산역점    NaN        I2       음식
# 317207  MA010120220812962899  메가커피공덕SK리더스뷰    NaN        I2       음식
# 321479  MA010120220813292922      메가커피신월경창    시장점        I2       음식
# 337754  MA010120220813957016          메가커피   화곡역점        I2       음식
# 343413  MA010120220814337194        메가커피신창    시장점        I2       음식
# 345626  MA0101202209A0061331          메가커피   발산역점        I2       음식
# 350301  MA010120220814193356      메가커피동소문점    NaN        I2       음식
# 357465  MA0101202302A0064663  메가커피신정이펜하우스점    NaN        I2       음식
# 402692  MA0101202307A0030912      메가커피금천현대    시장점        I2       음식
# 448573  MA0101202409A0144201        메가커피잠실    지하점        I2       음식
# 531560  MA0106202201A0299892      메가커피안국역점    NaN        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 11397       I212    비알코올     I21201       카페   I56221  ...
# 34455       I212    비알코올     I21201       카페   I56221  ...
# 79183       I212    비알코올     I21201       카페   I56221  ...
# 82047       I212    비알코올     I21201       카페   I56221  ...
# 89278       I212    비알코올     I21201       카페   I56221  ...
# 95297       I212    비알코올     I21201       카페   I56221  ...
# 141402      I212    비알코올     I21201       카페   I56221  ...
# 141793      I212    비알코올     I21201       카페   I56221  ...
# 166339      I212    비알코올     I21201       카페   I56221  ...
# 177125      I212    비알코올     I21201       카페   I56221  ...
# 185290      I212    비알코올     I21201       카페   I56221  ...
# 198677      I212    비알코올     I21201       카페   I56112  ...
# 206968      I212    비알코올     I21201       카페   I56221  ...
# 218327      I212    비알코올     I21201       카페   I56221  ...
# 229663      I212    비알코올     I21201       카페   I56221  ...
# 231371      I212    비알코올     I21201       카페   I56221  ...
# 231557      I212    비알코올     I21201       카페   I56221  ...
# 237155      I212    비알코올     I21201       카페   I56221  ...
# 246255      I212    비알코올     I21201       카페   I56191  ...
# 247539      I212    비알코올     I21201       카페   I56221  ...
# 253927      I212    비알코올     I21201       카페   I56221  ...
# 262489      I212    비알코올     I21201       카페   I56221  ...
# 263992      I212    비알코올     I21201       카페   I56221  ...
# 264906      I212    비알코올     I21201       카페   I56221  ...
# 266193      I212    비알코올     I21201       카페   I56221  ...
# 279603      I212    비알코올     I21201       카페   I56221  ...
# 281399      I212    비알코올     I21201       카페   I56221  ...
# 283780      I212    비알코올     I21201       카페   I56221  ...
# 297337      I212    비알코올     I21201       카페   I56221  ...
# 302814      I212    비알코올     I21201       카페   I56221  ...
# 304818      I212    비알코올     I21201       카페   I56221  ...
# 314600      I212    비알코올     I21201       카페   I56221  ...
# 317207      I212    비알코올     I21201       카페   I56221  ...
# 321479      I212    비알코올     I21201       카페   I56221  ...
# 337754      I212    비알코올     I21201       카페   I56221  ...
# 343413      I212    비알코올     I21201       카페   I56221  ...
# 345626      I212    비알코올     I21201       카페   I56221  ...
# 350301      I212    비알코올     I21201       카페   I56221  ...
# 357465      I212    비알코올     I21201       카페   I56221  ...
# 402692      I212    비알코올     I21201       카페   I56221  ...
# 448573      I212    비알코올     I21201       카페   I56221  ...
# 531560      I212    비알코올     I21201       카페   I56111  ...
#
#                            건물관리번호           건물명                  도로명주소  \
# 11397   1171010200100030000000001   잠실동잠실역지하도상가     서울특별시 송파구 올림픽로 265
# 34455   1150010600107230008009245             좌     서울특별시 강서구 강서로45길 6
# 79183   1150010500107570003000001  마곡나루역보타닉비즈타워  서울특별시 강서구 마곡중앙5로1길 20
# 82047   1171010800100000000000002        문정아이파크      서울특별시 송파구 법원로4길 6
# 89278   1162010100104640002033874           NaN      서울특별시 관악구 은천로 113
# 95297   1147010300105370008011026           NaN      서울특별시 양천구 신월로 175
# 141402  1153010100103370000000004     신도림푸르지오1차      서울특별시 구로구 경인로 661
# 141793  1123010600103660001016482          풍양빌딩     서울특별시 동대문구 장한로 116
# 166339  1168010100108210001000001      강남역지하도상가     서울특별시 강남구 테헤란로 101
# 177125  1171010600100220017000001       잠실레이크타워    서울특별시 송파구 석촌호수로 140
# 185290  1135010500105930002007922          동원빌딩     서울특별시 노원구 상계로3길 16
# 198677  1117010400100900015023923           NaN   서울특별시 용산구 한강대로 277-2
# 206968  1159010700101320008034007           NaN   서울특별시 동작구 동작대로27길 20
# 218327  1153010200101970028026783           NaN   서울특별시 구로구 디지털로31길 41
# 229663  1132010600106530018000001           NaN      서울특별시 도봉구 도봉로 727
# 231371  1138011000102230003000001       수색자이1단지      서울특별시 은평구 수색로 217
# 231557  1159010100100440018031551           NaN     서울특별시 동작구 노량진로 126
# 237155  1123010100100840005039356           NaN       서울특별시 동대문구 왕산로 3
# 246255  1165010700101280004000001         지하도상가     서울특별시 서초구 신반포로 200
# 247539  1129013300107800000027020         산장아파트     서울특별시 성북구 보국문로 167
# 253927  1156013200101140001019009           NaN     서울특별시 영등포구 도신로 234
# 262489  1120010700100010017019315           NaN     서울특별시 성동구 마조로1길 42
# 263992  1126010100106170001020698           NaN      서울특별시 중랑구 면목로 316
# 264906  1147010100110250009006373           NaN      서울특별시 양천구 은행정로 17
# 266193  1144012400102590005015806           NaN    서울특별시 마포구 동교로 235-1
# 279603  1162010100116730021032549           NaN   서울특별시 관악구 남부순환로 1861
# 281399  1159010200102090018024088           NaN      서울특별시 동작구 양녕로 193
# 283780  1135010600101540022010063           NaN    서울특별시 노원구 덕릉로83길 18
# 297337  1144010400101810001003288            일부       서울특별시 마포구 새창로 10
# 302814  1171010700101200004007204        가락우성2차    서울특별시 송파구 중대로12길 35
# 304818  1129012500101010002040214            일부   서울특별시 성북구 고려대로27길 15
# 314600  1135010500112670000009826        토마토파르코     서울특별시 노원구 동일로 1700
# 317207  1144010200102570003000001   공덕SK리더스뷰1단지     서울특별시 마포구 백범로31길 8
# 321479  1147010300104280007010632           NaN       서울특별시 양천구 월정로 53
# 337754  1150010300110740024012840           NaN      서울특별시 강서구 화곡로 160
# 343413  1132010700105690085014923           NaN      서울특별시 도봉구 덕릉로 238
# 345626  1150010200106740000025294          세민빌딩      서울특별시 강서구 강서로 380
# 350301  1129011900100420000043999           NaN      서울특별시 성북구 아리랑로 14
# 357465  1147010100113160000000001    신정이펜하우스3단지    서울특별시 양천구 신정이펜1로 50
# 402692  1154510300108520031005221           NaN      서울특별시 금천구 독산로 131
# 448573  1171010200100030000000001        잠실역2호선     서울특별시 송파구 올림픽로 265
# 531560  1111014800101040001018447           NaN     서울특별시 종로구 계동길 33-2
#
#          구우편번호 신우편번호  동정보  층정보  호정보          경도         위도
# 11397   138934  5510  NaN  NaN  NaN  127.100668  37.513453
# 34455   157835  7639  NaN    1  NaN  126.835813  37.548097
# 79183   157805  7788  NaN    1  NaN  126.826712  37.568672
# 82047   138888  5855  NaN  NaN  NaN  127.122108  37.482312
# 89278   151825  8729  NaN    1  NaN  126.947863  37.486959
# 95297   158840  8030  NaN    1  NaN  126.842540  37.518842
# 141402  152748  8208  NaN  NaN  NaN  126.887767  37.509532
# 141793  130840  2639  NaN    1  NaN  127.071053  37.570742
# 166339  135933  6134  NaN  NaN  NaN  127.028034  37.498662
# 177125  138837  5600  NaN    1  NaN  127.092505  37.507018
# 185290  139821  1693  NaN    1  NaN  127.062489  37.656981
# 198677  140807  4321  NaN    1  NaN  126.972221  37.543064
# 206968  156816  7008  NaN    1  NaN  126.980891  37.487636
# 218327  152719  8375  NaN  NaN  NaN  126.892756  37.485165
# 229663  132846  1350  NaN    1  NaN  127.043219  37.669351
# 231371  122873  3504  NaN    1  NaN  126.898722  37.579622
# 231557  156052  6928  NaN    1  NaN  126.939679  37.513165
# 237155  130810  2581  NaN    1  NaN  127.023660  37.576212
# 246255  137908  6545  NaN  NaN  NaN  127.005044  37.506225
# 247539  136768  2704  NaN  NaN  NaN  127.001892  37.616660
# 253927  150839  7351  NaN    1  NaN  126.917330  37.511980
# 262489  133817  4760  NaN    1  NaN  127.039421  37.561116
# 263992  131828  2249  NaN    1  NaN  127.088338  37.580074
# 264906  158861  8086  NaN    1  NaN  126.859684  37.521215
# 266193  121865  3984  NaN    1  NaN  126.924100  37.561053
# 279603  151726  8739  NaN    1  NaN  126.956868  37.479998
# 281399  156841  7048  NaN    1  NaN  126.943615  37.498535
# 283780  139856  1662  NaN    1  NaN  127.074414  37.660136
# 297337  121812  4168  NaN    1  NaN  126.951039  37.542120
# 302814  138806  5832  NaN    1  NaN  127.125719  37.491589
# 304818  136075  2842  NaN    1  NaN  127.029709  37.586996
# 314600  139876  1624  NaN  NaN  NaN  127.055820  37.680184
# 317207  121862  4147  NaN    1  NaN  126.948807  37.545218
# 321479  158832  7930  NaN    1  NaN  126.841510  37.524454
# 337754  157925  7715  NaN    1  NaN  126.839449  37.541165
# 343413  132917  1473  NaN  NaN  NaN  127.038658  37.638971
# 345626  157930  7591  NaN    1  NaN  126.838866  37.559472
# 350301  136054  2829  NaN  NaN  NaN  127.016396  37.593972
# 357465  158796  8050  NaN    1  NaN  126.829351  37.513355
# 402692  153856  8622  NaN    1  NaN  126.904898  37.458947
# 448573  138934  5510  NaN  NaN  NaN  127.101856  37.513866
# 531560  110801  3059  NaN  NaN  NaN  126.986528  37.578917
#
# [42 rows x 39 columns]

# %%
df[df["상호명"].str.contains('메가커피|메가엠지씨', case=False, na=False)]
# Out:
#                       상가업소번호              상호명   지점명 상권업종대분류코드 상권업종대분류명  \
# 5212    MA010120220800062311  메가엠지씨커피논현아크로힐스점   NaN        I2       음식
# 6045    MA010120220800090900  메가엠지씨커피천왕이펜하우스점   NaN        I2       음식
# 7002    MA010120220800105068        메가엠지씨커피신월  사거리점        I2       음식
# 11397   MA010120220800186190        식빵은여기메가커피   NaN        I2       음식
# 34455   MA010120220800505619            메가커피우   장산점        I2       음식
# ...                      ...              ...   ...       ...      ...
# 536196  MA0106202305A0036963        메가엠지씨커피석촌   한솔점        I2       음식
# 537112  MA0106202212A0036884     메가엠지씨커피신논현역점   NaN        I2       음식
# 537189  MA0106202306A0036928    메가엠지씨커피역삼GFC점   NaN        I2       음식
# 539813  MA0101202502A0100676  메가엠지씨커피래미안라그란데점   NaN        I2       음식
# 540482  MA0101202502A0103021    메가엠지씨커피쌍문세라믹점   NaN        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 5212        I212    비알코올     I21201       카페   I56221  ...
# 6045        I212    비알코올     I21201       카페   I56221  ...
# 7002        I212    비알코올     I21201       카페   I56221  ...
# 11397       I212    비알코올     I21201       카페   I56221  ...
# 34455       I212    비알코올     I21201       카페   I56221  ...
# ...          ...      ...       ...      ...      ...  ...
# 536196      I212    비알코올     I21201       카페   I56221  ...
# 537112      I212    비알코올     I21201       카페   I56221  ...
# 537189      I212    비알코올     I21201       카페   I56221  ...
# 539813      I212    비알코올     I21201       카페   I56221  ...
# 540482      I212    비알코올     I21201       카페   I56221  ...
#
#                            건물관리번호          건물명                 도로명주소   구우편번호  \
# 5212    1168010800102760000026382      아크로힐스논현     서울특별시 강남구 언주로 604  135833
# 6045    1153011100100270000000029   천왕이펜하우스4단지      서울특별시 구로구 천왕로 29  152130
# 7002    1147010300101660003011420          NaN  서울특별시 양천구 남부순환로40길 3  158829
# 11397   1171010200100030000000001  잠실동잠실역지하도상가    서울특별시 송파구 올림픽로 265  138934
# 34455   1150010600107230008009245            좌    서울특별시 강서구 강서로45길 6  157835
# ...                           ...          ...                   ...     ...
# 536196  1171010500102850004009886          NaN   서울특별시 송파구 백제고분로 354  138847
# 537112  1168010800101990005009372          NaN    서울특별시 강남구 강남대로 480  135827
# 537189  1168010100107380009028033          NaN     서울특별시 강남구 논현로 429  135924
# 539813  1123011000102570042002921      래미안라그란데  서울특별시 동대문구 이문로35길 12  130829
# 540482  1132010500100190015007350         다보빌딩      서울특별시 도봉구 도당로 14  132858
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 5212    6102  NaN    1  NaN  127.038399  37.509498
# 6045    8364  NaN    1  NaN  126.838493  37.480877
# 7002    7910  NaN  NaN  NaN  126.828318  37.535040
# 11397   5510  NaN  NaN  NaN  127.100668  37.513453
# 34455   7639  NaN    1  NaN  126.835813  37.548097
# ...      ...  ...  ...  ...         ...        ...
# 536196  5684  NaN    1  NaN  127.105620  37.504267
# 537112  6120  NaN  NaN  NaN  127.024565  37.505294
# 537189  6237  NaN    2  NaN  127.037421  37.499137
# 539813  2404  NaN  NaN  NaN  127.060233  37.600084
# 540482  1393  NaN    1  NaN  127.035167  37.659497
#
# [825 rows x 39 columns]

# %%
df_shop = df.copy()

# shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']
# 이디야|이디아커피|올리브영|컴포즈커피|빽다방|백다방|메가커피|메가엠지씨|메가MGC
# extract(): 특정 문자열을 포함하고 있으면 그 문자열을 반환, 포함하고 있지 않으면 NaN을 반환
df_shop['상호명'] = df_shop['상호명'].str.extract('({})'.format('|'.join(shop)))
df_shop['상호명']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 540512    NaN
# 540513    NaN
# 540514    NaN
# 540515    NaN
# 540516    NaN
# Name: 상호명, Length: 540517, dtype: object

# %%
df_shop = df_shop.dropna(subset=['상호명']).iloc[:, [0, 1, 14, 37, 38]].reset_index(drop=True)
# 상호명이 null일 때 drop해라. 그리고 0,1,14,37,38 열 남기고 날려라. 그리고 인덱스 리셋
# subset을 하는 이유는 상호명에 있는 null 값만 drop하기 위함임. 저걸 안하면 null값 다 drop 해버림
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220800024620    이디야   종로구  127.003181  37.582089
# 1     MA010120220800021713  컴포즈커피   종로구  127.015995  37.574051
# 2     MA010120220800026176    이디야   종로구  126.956322  37.601245
# 3     MA010120220800038013    이디야   종로구  126.991533  37.570096
# 4     MA010120220800033480    이디야   종로구  126.986745  37.568781
# ...                    ...    ...   ...         ...        ...
# 2305  MA0106202201A0056378    이디야  영등포구  126.923409  37.528635
# 2306  MA0106202201A0056379    이디야    중구  126.986564  37.566492
# 2307  MA0106202201A0056381    이디야   강남구  127.048190  37.503773
# 2308  MA0106202201A0056383    이디야   강남구  127.033119  37.514996
# 2309  MA0101202502A0103021  메가엠지씨   도봉구  127.035167  37.659497
#
# [2310 rows x 5 columns]

# %%
df_shop['상호명'] = df_shop['상호명'].str.replace('메가엠지씨', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('메가MGC', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('이디아커피', '이디야', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('백다방', '빽다방', regex=False)
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220800024620    이디야   종로구  127.003181  37.582089
# 1     MA010120220800021713  컴포즈커피   종로구  127.015995  37.574051
# 2     MA010120220800026176    이디야   종로구  126.956322  37.601245
# 3     MA010120220800038013    이디야   종로구  126.991533  37.570096
# 4     MA010120220800033480    이디야   종로구  126.986745  37.568781
# ...                    ...    ...   ...         ...        ...
# 2305  MA0106202201A0056378    이디야  영등포구  126.923409  37.528635
# 2306  MA0106202201A0056379    이디야    중구  126.986564  37.566492
# 2307  MA0106202201A0056381    이디야   강남구  127.048190  37.503773
# 2308  MA0106202201A0056383    이디야   강남구  127.033119  37.514996
# 2309  MA0101202502A0103021   메가커피   도봉구  127.035167  37.659497
#
# [2310 rows x 5 columns]

# %%
df_shop[df_shop["상호명"].str.contains('메가엠지씨', case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [상가업소번호, 상호명, 시군구명, 경도, 위도]
# Index: []

# %%
print(df_shop.shape)
print(df_starbucks.shape)
# Out:
# (2310, 5)
# (644, 4)

# %%
df_cross = df_shop.merge(df_starbucks, how='cross')
df_cross
# Out:
#                        상가업소번호   상호명 시군구명          경도         위도        지점명  \
# 0        MA010120220800024620   이디야  종로구  127.003181  37.582089  역삼아레나빌딩
# 1        MA010120220800024620   이디야  종로구  127.003181  37.582089   논현역사거리
# 2        MA010120220800024620   이디야  종로구  127.003181  37.582089  신사역성일빌딩
# 3        MA010120220800024620   이디야  종로구  127.003181  37.582089   국기원사거리
# 4        MA010120220800024620   이디야  종로구  127.003181  37.582089   대치재경빌딩
# ...                       ...   ...  ...         ...        ...        ...
# 1487635  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      상봉역
# 1487636  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497       묵동
# 1487637  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      망우동
# 1487638  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      양원역
# 1487639  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      중화역
#
#                                           지점주소       지점위도        지점경도
# 0                      서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1                     서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2                     서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3                     서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4                   서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ...                                        ...        ...         ...
# 1487635                서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 1487636  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 1487637                서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 1487638              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 1487639                   서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [1487640 rows x 9 columns]

# %% [markdown]
# # **4. 하버사인 공식**
# Haversine 공식은 구체(구면) 위의 두 점(위도와 경도로 표시됨) 사이의 최단 거리(대원 거리, great-circle distance)를 계산하는 방법입니다. 이 공식은 GPS 좌표(위도와 경도)를 활용하여 지구 표면 위의 거리 계산에 널리 사용됩니다.
#
# <img src = '![image.png](data:image/png;base64,...)'>

# %% [markdown]
# haversine은 파이썬 패키지(라이브러리)로, 두 지점의 위도·경도를 넣으면 자동으로 **지구 표면을 구(球)라 가정한 최단거리(대권 거리)**를 계산해 줍니다.
#
# ```
# from haversine import haversine
# # point1, point2는 [위도, 경도] 리스트나 튜플
# distance_m = haversine(point1, point2, unit='m')
# ```

# %%
! pip install haversine
# Out:
# Requirement already satisfied: haversine in /usr/local/lib/python3.11/dist-packages (2.9.0)

# %%
from haversine import haversine

# %%
df_cross['거리'] = df_cross.apply(lambda x: haversine([x['위도'], x['경도']], [x['지점위도'], x['지점경도']], unit='m'), axis=1)
df_cross
# Out:
#                        상가업소번호   상호명 시군구명          경도         위도        지점명  \
# 0        MA010120220800024620   이디야  종로구  127.003181  37.582089  역삼아레나빌딩
# 1        MA010120220800024620   이디야  종로구  127.003181  37.582089   논현역사거리
# 2        MA010120220800024620   이디야  종로구  127.003181  37.582089  신사역성일빌딩
# 3        MA010120220800024620   이디야  종로구  127.003181  37.582089   국기원사거리
# 4        MA010120220800024620   이디야  종로구  127.003181  37.582089   대치재경빌딩
# ...                       ...   ...  ...         ...        ...        ...
# 1487635  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      상봉역
# 1487636  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497       묵동
# 1487637  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      망우동
# 1487638  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      양원역
# 1487639  MA0101202502A0103021  메가커피  도봉구  127.035167  37.659497      중화역
#
#                                           지점주소       지점위도        지점경도  \
# 0                      서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1                     서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2                     서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3                     서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4                   서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ...                                        ...        ...         ...
# 1487635                서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 1487636  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 1487637                서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 1487638              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 1487639                   서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
#                    거리
# 0         9669.246029
# 1         8170.467737
# 2         7732.950240
# 3         9514.913964
# 4        11041.982974
# ...               ...
# 1487635   8299.147898
# 1487636   6116.326172
# 1487637   8640.842783
# 1487638   8592.394694
# 1487639   7469.408450
#
# [1487640 rows x 10 columns]

# %%
# 개별 매장들과 스타벅스와의 최소 거리
df_dis = df_cross.groupby(['상가업소번호','상호명'])['거리'].min().reset_index()
df_dis
# Out:
#                     상가업소번호    상호명           거리
# 0     MA010120220800021713  컴포즈커피   692.058445
# 1     MA010120220800024620    이디야    95.740366
# 2     MA010120220800026176    이디야  1115.073437
# 3     MA010120220800033480    이디야    81.912918
# 4     MA010120220800033806    이디야   352.787720
# ...                    ...    ...          ...
# 2305  MA0106202501A2292341   올리브영     7.329813
# 2306  MA0106202501A2304002    이디야   215.319431
# 2307  MA0106202502A2284422   올리브영   400.235185
# 2308  MA0106202502A2284581   올리브영   139.507587
# 2309  MA0106202502A2284582   올리브영    66.110221
#
# [2310 rows x 3 columns]

# %%
# 각 프렌차이즈 별 스타벅스와의 평균 거리
df_dis.groupby('상호명')['거리'].mean()
# Out:
# 상호명
# 메가커피     389.117743
# 빽다방      306.873161
# 올리브영     217.008179
# 이디야      393.076045
# 컴포즈커피    356.917701
# Name: 거리, dtype: float64

# %%
# agg(): 다중 집계작업을 간단하게 해주는 함수
df_dis.groupby(['상호명'])['거리'].agg(['mean','count'])
# Out:
#              mean  count
# 상호명
# 메가커피   389.117743    835
# 빽다방    306.873161    371
# 올리브영   217.008179    179
# 이디야    393.076045    494
# 컴포즈커피  356.917701    431

# %%
# 거리를 입력하면 프렌차이즈 별 스타벅스와의 평균거리와 매장개수를 출력하는 함수
def distance(x):
    dis = df_dis['거리'] <= x
    return df_dis[dis].groupby('상호명')['거리'].agg(['mean', 'count'])

distance(100)
# Out:
#             mean  count
# 상호명
# 메가커피   59.585891    148
# 빽다방    64.500764     93
# 올리브영   56.060383     74
# 이디야    66.871194     87
# 컴포즈커피  62.717747     86

# %%
# !pip install pandasecharts
# Out:
# Collecting pandasecharts
#   Downloading pandasecharts-0.5-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandasecharts) (2.2.2)
# Collecting pyecharts>=1.0.0 (from pandasecharts)
#   Downloading pyecharts-2.0.8-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.1.6)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.16.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.20.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasecharts) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasecharts) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandasecharts) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pyecharts>=1.0.0->pandasecharts) (3.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->pyecharts>=1.0.0->pandasecharts) (0.2.13)
# Downloading pandasecharts-0.5-py3-none-any.whl (15 kB)
# Downloading pyecharts-2.0.8-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: pyecharts, pandasecharts
# Successfully installed pandasecharts-0.5 pyecharts-2.0.8

# %%
df_100 = distance(100).reset_index()
df_100
# Out:
#      상호명       mean  count
# 0   메가커피  59.585891    148
# 1    빽다방  64.500764     93
# 2   올리브영  56.060383     74
# 3    이디야  66.871194     87
# 4  컴포즈커피  62.717747     86

# %%
import IPython
from pandasecharts import echart

df_100.echart.pie(x='상호명', y='count', figsize=(600, 400),
                  radius=['20%', '60%'], label_opts={'position':'outer'},
                  title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                  legend_opts={'pos_right':'0%', 'orient':'vertical'},
                  subtitle='100m 이내 매장수', init_opts={'bg_color': 'white'}).render()

IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="https://assets.pyecharts.org/assets/v5/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="ac562077994640eda47ff1dede98ff23" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_ac562077994640eda47ff1dede98ff23 = echarts.init(
#             document.getElementById('ac562077994640eda47ff1dede98ff23'), 'white', {renderer: 'canvas'});
#         var option_ac562077994640eda47ff1dede98ff23 = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "count",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\uba54\uac00\ucee4\ud53c",
#                     "value": 148
#                 },
#                 {
#                     "name": "\ube7d\ub2e4\ubc29",
#                     "value": 93
#                 },
#                 {
#                     "name": "\uc62c\ub9ac\ube0c\uc601",
#                     "value": 74
#                 },
#                 {
#                     "name": "\uc774\ub514\uc57c",
#                     "value": 87
#                 },
#                 {
#                     "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                     "value": 86
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outer",
#                 "margin": 8,
#                 "formatter": "{b}:{d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uba54\uac00\ucee4\ud53c",
#                 "\ube7d\ub2e4\ubc29",
#                 "\uc62c\ub9ac\ube0c\uc601",
#                 "\uc774\ub514\uc57c",
#                 "\ucef4\ud3ec\uc988\ucee4\ud53c"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "0%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\ucee4\ud53c \ud504\ub80c\ucc28\uc774\uc988\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \uc2a4\ud0c0\ubc85\uc2a4 \uc606\uc778\uac00?",
#             "target": "blank",
#             "subtext": "100m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_ac562077994640eda47ff1dede98ff23.setOption(option_ac562077994640eda47ff1dede98ff23);
#     </script>
# </body>
# </html>

# %%
from pyecharts.charts import Timeline, Grid

tl = Timeline({'width':'600px', 'height':'400px'})

for i in [1000, 100, 50, 30]:
    df_d = distance(i).reset_index()
    pie1 = df_d.echart.pie(x='상호명', y='count', figsize=(600, 400),
                    radius=['20%', '60%'], label_opts={'position':'outer'},
                    title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                    legend_opts={'pos_right':'0%', 'orient':'vertical'},
                    subtitle='{}m 이내 매장수'.format(i), init_opts={'bg_color': 'white'})
    tl.add(pie1, '{}m'.format(i)).render()
IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="https://assets.pyecharts.org/assets/v5/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="76697b9a156d49e1ac7ebf4c7e03312e" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_76697b9a156d49e1ac7ebf4c7e03312e = echarts.init(
#             document.getElementById('76697b9a156d49e1ac7ebf4c7e03312e'), 'white', {renderer: 'canvas'});
#         var option_76697b9a156d49e1ac7ebf4c7e03312e = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "count",
#                 "colorBy": "data",
#                 "legendHoverLink": true,
#                 "selectedMode": false,
#                 "selectedOffset": 10,
#                 "clockwise": true,
#                 "startAngle": 90,
#                 "minAngle": 0,
#                 "minShowLabelAngle": 0,
#                 "avoidLabelOverlap": true,
#                 "stillShowZeroSum": true,
#                 "percentPrecision": 2,
#                 "showEmptyCircle": true,
#                 "emptyCircleStyle": {
#                     "color": "lightgray",
#                     "borderColor": "#000",
#                     "borderWidth": 0,
#                     "borderType": "solid",
#                     "borderDashOffset": 0,
#                     "borderCap": "butt",
#                     "borderJoin": "bevel",
#                     "borderMiterLimit": 10,
#                     "opacity": 1
#                 },
#                 "data": [
#                     {
#                         "name": "\uba54\uac00\ucee4\ud53c",
#                         "value": 22
#                     },
#                     {
#                         "name": "\ube7d\ub2e4\ubc29",
#                         "value": 8
#                     },
#                     {
#                         "name": "\uc62c\ub9ac\ube0c\uc601",
#                         "value": 17
#                     },
#                     {
#                         "name": "\uc774\ub514\uc57c",
#                         "value": 8
#                     },
#                     {
#                         "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                         "value": 13
#                     }
#                 ],
#                 "radius": [
#                     "20%",
#                     "60%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "outer",
#                     "margin": 8,
#                     "formatter": "{b}:{d}%",
#                     "valueAnimation": false
#                 },
#                 "labelLine": {
#                     "show": true,
#                     "showAbove": false,
#                     "length": 15,
#                     "length2": 15,
#                     "smooth": false,
#                     "minTurnAngle": 90,
#                     "maxSurfaceAngle": 90
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "1000m",
#                 "100m",
#                 "50m",
#                 "30m"
#             ]
#         },
#         "legend": [
#             {
#                 "data": [
#                     "\uba54\uac00\ucee4\ud53c",
#                     "\ube7d\ub2e4\ubc29",
#                     "\uc62c\ub9ac\ube0c\uc601",
#                     "\uc774\ub514\uc57c",
#                     "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                 ],
#                 "selected": {},
#                 "show": true,
#                 "right": "0%",
#                 "orient": "vertical",
#                 "padding": 5,
#                 "itemGap": 10,
#                 "itemWidth": 25,
#                 "itemHeight": 14,
#                 "backgroundColor": "transparent",
#                 "borderColor": "#ccc",
#                 "borderRadius": 0,
#                 "pageButtonItemGap": 5,
#                 "pageButtonPosition": "end",
#                 "pageFormatter": "{current}/{total}",
#                 "pageIconColor": "#2f4554",
#                 "pageIconInactiveColor": "#aaa",
#                 "pageIconSize": 15,
#                 "animationDurationUpdate": 800,
#                 "selector": false,
#                 "selectorPosition": "auto",
#                 "selectorItemGap": 7,
#                 "selectorButtonGap": 10
#             }
#         ]
#     },
#     "options": [
#         {
#             "backgroundColor": "white",
#             "legend": [
#                 {
#                     "data": [
#                         "\uba54\uac00\ucee4\ud53c",
#                         "\ube7d\ub2e4\ubc29",
#                         "\uc62c\ub9ac\ube0c\uc601",
#                         "\uc774\ub514\uc57c",
#                         "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14,
#                     "backgroundColor": "transparent",
#                     "borderColor": "#ccc",
#                     "borderRadius": 0,
#                     "pageButtonItemGap": 5,
#                     "pageButtonPosition": "end",
#                     "pageFormatter": "{current}/{total}",
#                     "pageIconColor": "#2f4554",
#                     "pageIconInactiveColor": "#aaa",
#                     "pageIconSize": 15,
#                     "animationDurationUpdate": 800,
#                     "selector": false,
#                     "selectorPosition": "auto",
#                     "selectorItemGap": 7,
#                     "selectorButtonGap": 10
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "colorBy": "data",
#                     "legendHoverLink": true,
#                     "selectedMode": false,
#                     "selectedOffset": 10,
#                     "clockwise": true,
#                     "startAngle": 90,
#                     "minAngle": 0,
#                     "minShowLabelAngle": 0,
#                     "avoidLabelOverlap": true,
#                     "stillShowZeroSum": true,
#                     "percentPrecision": 2,
#                     "showEmptyCircle": true,
#                     "emptyCircleStyle": {
#                         "color": "lightgray",
#                         "borderColor": "#000",
#                         "borderWidth": 0,
#                         "borderType": "solid",
#                         "borderDashOffset": 0,
#                         "borderCap": "butt",
#                         "borderJoin": "bevel",
#                         "borderMiterLimit": 10,
#                         "opacity": 1
#                     },
#                     "data": [
#                         {
#                             "name": "\uba54\uac00\ucee4\ud53c",
#                             "value": 782
#                         },
#                         {
#                             "name": "\ube7d\ub2e4\ubc29",
#                             "value": 357
#                         },
#                         {
#                             "name": "\uc62c\ub9ac\ube0c\uc601",
#                             "value": 174
#                         },
